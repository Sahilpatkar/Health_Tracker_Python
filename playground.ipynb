# %%
from Kafka.kafka_producer_avro import send_to_kafka_avro
from Kafka.kafka_producer import send_to_kafka
import numpy as np

sample_dict = {
    "user": "shashank",
    "context": {
        "name": "SHASHANK ANANT PATKAR",
        "date": "2024-08-25T12:01:00",
        "gender": "MALE",
        "location": "Supreme Pallacio Baner, Pune"
    },
    "params": {
        "Hemoglobin (Hb)": {
            "value": 15.0,
            "unit": "13",
            "remark": ""
        },
        "Total Leucocytes (WBC) count": {
            "value": 7700.0,
            "unit": "4000",
            "remark": ""
        },
        "Platelet count": {
            "value": 303000.0,
            "unit": "150000",
            "remark": ""
        },
        "Red blood cell (RBC) count": {
            "value": 5.15,
            "unit": "4",
            "remark": ""
        },
        "PCV (Packed Cell Volume)": {
            "value": 46.0,
            "unit": "38",
            "remark": ""
        },
        "MCV (Mean Corpuscular Volume)": {
            "value": 89.3,
            "unit": "78",
            "remark": ""
        },
        "MCH (Mean Corpuscular Hb)": {
            "value": 29.2,
            "unit": "27",
            "remark": ""
        },
        "MCHC (Mean Corpuscular Hb Conc.)": {
            "value": 32.7,
            "unit": "31",
            "remark": ""
        },
        "RDW (RBC distribution width)": {
            "value": 13.5,
            "unit": "11",
            "remark": ""
        },
        "MPV (Mean Platelet Volume)": {
            "value": 7.4,
            "unit": "7",
            "remark": ""
        },
        "Neutrophils": {
            "value": 51.0,
            "unit": "40",
            "remark": ""
        },
        "Absolute Neutrophils": {
            "value": 3927.0,
            "unit": "2000",
            "remark": ""
        },
        "Eosinophils": {
            "value": 8.0,
            "unit": "1",
            "remark": ""
        },
        "Absolute Eosinophils": {
            "value": 616.0,
            "unit": "20",
            "remark": ""
        },
        "Basophils": {
            "value": 0.0,
            "unit": "0",
            "remark": ""
        },
        "Absolute Basophils": {
            "value": 0.0,
            "unit": "0",
            "remark": ""
        },
        "Lymphocytes": {
            "value": 32.0,
            "unit": "20",
            "remark": ""
        },
        "Absolute Lymphocytes": {
            "value": 2464.0,
            "unit": "1000",
            "remark": ""
        },
        "Monocytes": {
            "value": 9.0,
            "unit": "2",
            "remark": ""
        },
        "Absolute Monocytes": {
            "value": 693.0,
            "unit": "200",
            "remark": ""
        },
        "Cholesterol (Total)": {
            "value": 143.0,
            "unit": "Desirable",
            "remark": ""
        },
        "Triglycerides": {
            "value": 107.0,
            "unit": "Normal",
            "remark": ""
        },
        "HDL Cholesterol": {
            "value": 46.0,
            "unit": "Males",
            "remark": ""
        },
        "VLDL Cholesterol": {
            "value": 21,
            "unit": "mg/dL",
            "remark": "< 30 mg/dL"
        },
        "LDL Cholesterol": {
            "value": 80.0,
            "unit": "Optimal",
            "remark": ""
        },
        "Cholesterol/HDL Ratio": {
            "value": 3.11,
            "unit": "-",
            "remark": "Males : Acceptable ratio </= 5.00"
        },
        "LDL/HDL Ratio": {
            "value": 1.74,
            "unit": "",
            "remark": "Males: Acceptable ratio </= 3.60"
        },
        "Apolipoprotein A1": {
            "value": 154.0,
            "unit": "",
            "remark": ""
        },
        "Apolipoprotein B": {
            "value": 69.0,
            "unit": "Desirable",
            "remark": ""
        },
        "ApoB/A1 Ratio": {
            "value": 0.45,
            "unit": "",
            "remark": "Lower Risk : < 0.7, Average Risk : 0.7 to 0.9, Higher Risk : > 0.9"
        },
        "Bilirubin-Total": {
            "value": 2.13,
            "unit": "0",
            "remark": ""
        },
        "Bilirubin-Conjugated": {
            "value": 0.7,
            "unit": "Upto",
            "remark": ""
        },
        "Bilirubin-Unconjugated": {
            "value": 1.43,
            "unit": "0",
            "remark": ""
        },
        "SGOT (AST)": {
            "value": 40.0,
            "unit": "",
            "remark": ""
        },
        "SGPT (ALT)": {
            "value": 42.0,
            "unit": "7",
            "remark": ""
        },
        "Alkaline Phosphatase": {
            "value": 92.0,
            "unit": "Adult",
            "remark": ""
        },
        "Protein (Total)": {
            "value": 7.1,
            "unit": "6",
            "remark": ""
        },
        "Albumin": {
            "value": 4.5,
            "unit": "3",
            "remark": ""
        },
        "Globulin": {
            "value": 2.6,
            "unit": "2",
            "remark": ""
        },
        "Plasma Glucose Fasting": {
            "value": 92.0,
            "unit": "Fasting",
            "remark": ""
        },
        "Urea": {
            "value": 27.0,
            "unit": "17",
            "remark": ""
        },
        "BUN (Blood Urea Nitrogen)": {
            "value": 12.62,
            "unit": "mg/dL",
            "remark": "BUN-Blood Urea Nitrogen, serum by calculation"
        },
        "Creatinine": {
            "value": 0.92,
            "unit": "0",
            "remark": ""
        },
        "Vitamin D": {
            "value": 36.2,
            "unit": "Severe",
            "remark": ""
        },
        "Vitamin B12": {
            "value": 963.0,
            "unit": "187",
            "remark": ""
        },
        "Insulin Fasting": {
            "value": 10.6,
            "unit": "2",
            "remark": ""
        },
        "Free T3": {
            "value": 2.66,
            "unit": "1",
            "remark": ""
        },
        "Free T4": {
            "value": 1.02,
            "unit": "0",
            "remark": ""
        },
        "TSH (Ultrasensitive)": {
            "value": 4.83,
            "unit": "\u00b5IU/mL",
            "remark": "Suggested Anti thyroid antibodies & follow up."
        },
        "HbA1C": {
            "value": 5.4,
            "unit": "4",
            "remark": ""
        },
        "Estimated Average Glucose (eAG)": {
            "value": 108.0,
            "unit": "mg/dL",
            "remark": ""
        },
        "PSA": {
            "value": 3.895,
            "unit": "Age",
            "remark": ""
        },
        "CRP(hs)": {
            "value": 0.44,
            "unit": "See",
            "remark": ""
        },
        "Calcium": {
            "value": 8.8,
            "unit": "Adult",
            "remark": ""
        },
        "ESR (Erythrocyte Sedimentation Rate)": {
            "value": 3,
            "unit": "mm/hr",
            "remark": "Male under 50 Yrs : Upto 15mm/hr. Male 50 - 85 Yrs : Upto 20mm/hr. Male > 85 yrs : Upto 30mm/hr."
        },
        "Urine Routine Examination pH": {
            "value": 6.5,
            "unit": "",
            "remark": "4.6 - 8.0"
        },
        "Urine Routine Examination Protein": {
            "value": "Absent",
            "unit": "",
            "remark": "Absent"
        },
        "Urine Routine Examination Glucose": {
            "value": "Absent",
            "unit": "",
            "remark": "Absent"
        },
        "Urine Routine Examination Acetone": {
            "value": "Absent",
            "unit": "",
            "remark": ""
        },
        "Urine Routine Examination Bile Pigments": {
            "value": "Absent",
            "unit": "",
            "remark": ""
        },
        "Urine Routine Examination Urobilinogen": {
            "value": "Not significant",
            "unit": "-",
            "remark": ""
        },
        "Urine Routine Examination RBCs": {
            "value": "Absent",
            "unit": "",
            "remark": "0 - 2 per hpf"
        },
        "Urine Routine Examination Pus cells": {
            "value": "2-3",
            "unit": "per hpf",
            "remark": "0 - 5 per hpf"
        },
        "Urine Routine Examination Epithelial cells": {
            "value": "1-2",
            "unit": "per hpf",
            "remark": "Normal range: 0 - 5 per hpf"
        },
        "Urine Routine Examination Casts": {
            "value": "Not detected",
            "unit": "",
            "remark": ""
        },
        "Urine Routine Examination Crystals": {
            "value": "Not detected",
            "unit": "-",
            "remark": ""
        },
        "Urine Routine Examination Quantity Examined": {
            "value": 5.0,
            "unit": "ml",
            "remark": ""
        },
        "Urine Routine Examination Appearance": {
            "value": "Clear",
            "unit": "",
            "remark": ""
        },
        "Urine Routine Examination Colour": {
            "value": "Yellow",
            "unit": "-",
            "remark": "-"
        }
    }
}

send_to_kafka_avro(sample_dict,"health-report-data-avro")

# %%
def infinite_numbers():
    num = 0
    while True:
        yield num
        num += 1

gen = infinite_numbers()
for _ in range(5):
    print(next(gen))
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for _ in range(5):
    print(next(gen))
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
from datetime import datetime
date_str = '2021-02-12T18:08:00'
date_str = date_str.split("T")[0]
datetime.strptime(date_str, '%Y-%m-%d').date()
# Out:
# datetime.date(2021, 2, 12)

# %%
from pymongo import MongoClient
import json
client = MongoClient("mongodb://root:123456@localhost:27017/")
db = client["mydatabase"]
collection = db["mycollection"]

# %%
data = {"name":"sahil","age":24,"parameters":{"RBC_count":100,"O2_percentage":90}}

# %%
if isinstance(data, list):
    collection.insert_many(data)
else:
    collection.insert_one(data)
